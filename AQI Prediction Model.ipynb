# %% [markdown]
# # AQI Prediction Model Using Python

# %% [markdown]
# - PM2.5 PM10
# - NO, NO2
# - NH3 - Ammonia
# - CO
# - So2
# - O3
# - Benzene,Toluene,xylene

# %%
pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("air quality data.csv")
df.head() # Top 5 rows only shown
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
# Shape or count of rows & columns
df.shape
# Out:
# (29531, 16)

# %%
# Information (to look into aspect like datatype and other)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
# To know the duplicate values in dataset
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29526    False
# 29527    False
# 29528    False
# 29529    False
# 29530    False
# Length: 29531, dtype: bool

# %%
# to get summarized result to know duplicate values in dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# To check missing values in dataset
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
# To Drop the rows where 'AQI' has missing values.
df.dropna(subset=['AQI'],inplace=True)

# %%
# To see the rows are dropped and in descending order.
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        15372
# PM10           7086
# NH3            6536
# Toluene        5826
# Benzene        3535
# NOx            1857
# O3              807
# PM2.5           678
# SO2             605
# CO              445
# NO2             391
# NO              387
# Date              0
# City              0
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
# to check the change in total no. of data set value.
df.shape
# Out:
# (24850, 16)

# %%
# Summary of statistics in the dataset
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24172.000000  17764.000000  24463.000000  24459.000000  22993.000000
# mean      67.476613    118.454435     17.622421     28.978391     32.289012
# std       63.075398     89.487976     22.421138     24.627054     30.712855
# min        0.040000      0.030000      0.030000      0.010000      0.000000
# 25%       29.000000     56.777500      5.660000     11.940000     13.110000
# 50%       48.785000     96.180000      9.910000     22.100000     23.680000
# 75%       80.925000    150.182500     20.030000     38.240000     40.170000
# max      914.940000    917.080000    390.680000    362.210000    378.240000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  18314.000000  24405.000000  24245.000000  24043.000000  21315.000000
# mean      23.848366      2.345267     14.362933     34.912885      3.458668
# ...

# %%
# To transpose row and column
df.describe().T
# Out:
#            count        mean         std    min      25%      50%       75%  \
# PM2.5    24172.0   67.476613   63.075398   0.04  29.0000   48.785   80.9250
# PM10     17764.0  118.454435   89.487976   0.03  56.7775   96.180  150.1825
# NO       24463.0   17.622421   22.421138   0.03   5.6600    9.910   20.0300
# NO2      24459.0   28.978391   24.627054   0.01  11.9400   22.100   38.2400
# NOx      22993.0   32.289012   30.712855   0.00  13.1100   23.680   40.1700
# NH3      18314.0   23.848366   25.875981   0.01   8.9600   16.310   30.3600
# CO       24405.0    2.345267    7.075208   0.00   0.5900    0.930    1.4800
# SO2      24245.0   14.362933   17.428693   0.01   5.7300    9.220   15.1400
# O3       24043.0   34.912885   21.724525   0.01  19.2500   31.250   46.0800
# Benzene  21315.0    3.458668   16.036020   0.00   0.2300    1.290    3.3400
# Toluene  19024.0    9.525714   20.881085   0.00   1.0275    3.575   10.1800
# ...

# %%
# Percentage of the null values.
null_values_percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
null_values_percentage
# Out:
# Xylene        61.859155
# PM10          28.515091
# NH3           26.301811
# Toluene       23.444668
# Benzene       14.225352
# NOx            7.472837
# O3             3.247485
# PM2.5          2.728370
# SO2            2.434608
# CO             1.790744
# NO2            1.573441
# NO             1.557344
# Date           0.000000
# City           0.000000
# AQI            0.000000
# AQI_Bucket     0.000000
# dtype: float64

# %% [markdown]
# #### Key Consideration:
# - Xylene has the highest percentage of missing values - 61.86%
# - PM10 and NH3 28-26%

# %% [markdown]
# # Week 2 - Visualization

# %%
# Univariate analysis
df['Xylene'].plot(kind='hist', figsize=(10, 5), label="Xylene Distribution")
plt.legend()  # This works because a label is defined
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Univariate analysis
#       2 df['Xylene'].plot(kind='hist', figsize=(10, 5), label="Xylene Distribution")
# ----> 3 plt.legend()  # This works because a label is defined
#       4 plt.show()
#
# TypeError: 'module' object is not callable

# %%
df['PM10'].plot(kind='hist', figsize=(10, 5), label="PM10 Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['NH3'].plot(kind='hist', figsize=(10, 5), label="NH3 Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['Toluene'].plot(kind='hist', figsize=(10, 5), label="Toluene Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['Benzene'].plot(kind='hist', figsize=(10, 5), label="Benzene Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['NOx'].plot(kind='hist', figsize=(10, 5), label="NOx Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['O3'].plot(kind='hist', figsize=(10, 5), label="O3 Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['PM2.5'].plot(kind='hist', figsize=(10, 5), label="PM2.5 Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['SO2'].plot(kind='hist', figsize=(10, 5), label="SO2 Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['CO'].plot(kind='hist', figsize=(10, 5), label="CO Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
df['AQI'].plot(kind='hist', figsize=(10, 5), label="AQI Distribution")
plt.legend()  # This works because a label is defined
plt.show()

# %%
# Distribution of AQI from 2015 to 2020
sns.displot(df, x='AQI', color='purple')
plt.show()

# %%
# Bivariate

sns.set_theme(style="darkgrid")
graph = sns.catplot (x="City", kind='count', data=df, height=5, aspect=3)
graph.set_xticklabels(rotation=90)

# %%
sns.set_theme(style="darkgrid")
graph = sns.catplot (x="City", kind='count', data=df, col="AQI_Bucket",
                     col_wrap=2, height=3.5, aspect=3)
graph.set_xticklabels(rotation=90)

# %%
graph1 = sns.catplot(x='City', y='PM2.5', kind='box', data=df, height=5,aspect=3)
graph1.set_xticklabels(rotation=90)

# %%
graph2 = sns.catplot(x='City', y='NO2', kind='box', data=df, height=5,aspect=3)
graph2.set_xticklabels(rotation=90)

# %%
graph3 = sns.catplot(x='City', y='O3', kind='box', data=df, height=5,aspect=3)
graph3.set_xticklabels(rotation=90)

# %%
graph4 = sns.catplot(x='City', y='SO2', kind='box', data=df, height=5,aspect=3)
graph4.set_xticklabels(rotation=90)

# %%
graph5 = sns.catplot(x='AQI_Bucket', kind='count', data=df, height=5,aspect=3)
graph5.set_xticklabels(rotation=90)

# %%
# to check the null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        15372
# PM10           7086
# NH3            6536
# Toluene        5826
# Benzene        3535
# NOx            1857
# O3              807
# PM2.5           678
# SO2             605
# CO              445
# NO2             391
# NO              387
# Date              0
# City              0
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
df.describe().loc['mean']
# Out:
# PM2.5       67.476613
# PM10       118.454435
# NO          17.622421
# NO2         28.978391
# NOx         32.289012
# NH3         23.848366
# CO           2.345267
# SO2         14.362933
# O3          34.912885
# Benzene      3.458668
# Toluene      9.525714
# Xylene       3.588683
# AQI        166.463581
# Name: mean, dtype: float64

# %%
df = df.replace({
    "PM2.5":{np.nan:67.476613},
    "PM10":{np.nan:118.454435},
    "NO":{np.nan:17.622421},
    "NO2":{np.nan:28.978391},
    "NOx":{np.nan:32.289012},
    "NH3":{np.nan:23.848366},
    "CO":{np.nan:2.345267},
    "SO2":{np.nan:14.362933},
    "O3":{np.nan:34.912885},
    "Benzene":{np.nan:3.458668},
    "Toluene":{np.nan:9.525714},
    "Xylene":{np.nan:3.588683}
})

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df = df.drop(['AQI_Bucket'], axis=1)

# %%
df.head()
# Out:
#          City        Date   PM2.5        PM10     NO    NO2    NOx        NH3  \
# 28  Ahmedabad  2015-01-29   83.13  118.454435   6.93  28.71  33.72  23.848366
# 29  Ahmedabad  2015-01-30   79.84  118.454435  13.85  28.68  41.08  23.848366
# 30  Ahmedabad  2015-01-31   94.52  118.454435  24.39  32.66  52.61  23.848366
# 31  Ahmedabad  2015-02-01  135.99  118.454435  43.48  42.08  84.57  23.848366
# 32  Ahmedabad  2015-02-02  178.33  118.454435  54.56  35.31  72.80  23.848366
#
#        CO    SO2      O3  Benzene  Toluene  Xylene    AQI
# 28   6.93  49.52   59.76     0.02     0.00    3.14  209.0
# 29  13.85  48.49   97.07     0.04     0.00    4.81  328.0
# 30  24.39  67.39  111.33     0.24     0.01    7.67  514.0
# 31  43.48  75.23  102.70     0.40     0.04   25.87  782.0
# 32  54.56  55.04  107.38     0.46     0.06   35.61  914.0

# %%
sns.boxplot(data=df[['PM2.5','PM10']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['NO','NO2','NOx','NH3']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['O3','SO2']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['CO','AQI']])
# Out:
# <Axes: >

# %%
# IQR mETHOD - Q3 Q1
def replace_outliers(df):
    for column in df.select_dtypes(include=['number']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lb = Q1 - 1.5 * IQR
        ub = Q3 + 1.5 * IQR
        df[column] = df[column].apply(
            lambda x: Q1 if x < lb else (Q3 if x> ub else x)
        )
    return df

# %%
df = replace_outliers(df)

# %%
df.describe().transpose()
# Out:
#            count        mean        std    min    25%         50%         75%  \
# PM2.5    24850.0   55.174281  31.829575   0.04  29.56   50.165000   79.505625
# PM10     24850.0  101.351323  39.079916   0.03  71.78  118.454435  122.955625
# NO       24850.0   12.507694   8.762015   0.03   5.72   10.075000   19.710000
# NO2      24850.0   25.901114  16.669494   0.01  12.09   22.535000   37.910000
# NOx      24850.0   26.574513  16.138682   0.00  14.03   25.720000   38.170000
# NH3      24850.0   19.486584   9.630370   0.01  11.28   23.848366   24.710000
# CO       24850.0    1.040507   0.615436   0.00   0.59    0.950000    1.530000
# SO2      24850.0   10.334743   5.680901   0.01   5.79    9.430000   14.890000
# O3       24850.0   33.177781  17.487724   0.01  19.64   32.060000   45.395625
# Benzene  24850.0    2.098520   1.828135   0.00   0.34    1.810000    3.458668
# Toluene  24850.0    6.222709   4.696068   0.00   1.58    6.790000    9.525714
# ...

# %%
sns.boxplot(data=df[['PM2.5','PM10']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['O3','SO2']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['Benzene','Toluene','Xylene']])
# Out:
# <Axes: >

# %%
sns.displot(df, x='AQI', color='red')

# %%
df1 = df.drop(columns=['City'])

# %%
print(df1.dtypes)
# Out:
# Date        object
# PM2.5      float64
# PM10       float64
# NO         float64
# NO2        float64
# NOx        float64
# NH3        float64
# CO         float64
# SO2        float64
# O3         float64
# Benzene    float64
# Toluene    float64
# Xylene     float64
# AQI        float64
# dtype: object

# %%
# Assuming df1 is your DataFrame. convert 'Date' to Datetime
df1['Date'] = pd.to_datetime(df1['Date'], errors='coerce')

# %%
# Exclude 'Date' from correlation
numerical_df = df1.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()

# %%
# Multivariate Analysis - Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True)
plt.show()

# %%
# Heatmap in coolwarm
plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.show()
